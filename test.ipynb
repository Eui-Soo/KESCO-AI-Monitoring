# %%
import pandas as pd

# %%
df=pd.read_parquet('C:\\Users\\robov\\OneDrive\\Desktop\\kesco\\files\\preprocess\\SITE_1_BMS_EQMT-BAT-05\\2026-07-03\\battery_preprocessed.parquet')
df['cel_volt_01'].plot()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >
